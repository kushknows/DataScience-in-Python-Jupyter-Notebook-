# %%
import pandas as pd
train=pd.read_csv(r'C:\Users\KUSH\Downloads\Digit Recognizer\traindata.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train['Gender_map']=train.Gender.map({'male':0,'female':1}) #to convert string into int

# %%
train.head()
train.Name.split(' ')[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-c3d621aabe71> in <module>()
#       1 train.head()
# ----> 2 train.Name.split(' ')[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
import numpy as nm
# .apply()is func in numpy
train.Fare.apply(nm.ceil) #ceil= upper roundoff
train.Fare.apply(nm.floor) #floor= lowe roundoff
# Out:
# 0        7.0
# 1       71.0
# 2        7.0
# 3       53.0
# 4        8.0
# 5        8.0
# 6       51.0
# 7       21.0
# 8       11.0
# 9       30.0
# 10      16.0
# 11      26.0
# 12       8.0
# 13      31.0
# 14       7.0
# 15      16.0
# 16      29.0
# 17      13.0
# 18      18.0
# 19       7.0
# 20      26.0
# 21      13.0
# 22       8.0
# 23      35.0
# 24      21.0
# 25      31.0
# 26       7.0
# 27     263.0
# 28       7.0
# 29       7.0
#        ...
# 861     11.0
# 862     25.0
# 863     69.0
# 864     13.0
# 865     13.0
# 866     13.0
# 867     50.0
# 868      9.0
# 869     11.0
# 870      7.0
# 871     52.0
# 872      5.0
# 873      9.0
# 874     24.0
# 875      7.0
# 876      9.0
# 877      7.0
# 878      7.0
# 879     83.0
# 880     26.0
# 881      7.0
# 882     10.0
# 883     10.0
# 884      7.0
# 885     29.0
# 886     13.0
# 887     30.0
# 888     23.0
# 889     30.0
# 890      7.0
# Name: Fare, dtype: float64

# %%
z='mittal , kush'
z.split(',')
# Out:
# ['mittal ', ' kush']

# %%
for i in range(891):
  print(train.PassengerId[i],train.Name[i].split(',')[0])
# Out:
# 1 Braund
# 2 Cumings
# 3 Heikkinen
# 4 Futrelle
# 5 Allen
# 6 Moran
# 7 McCarthy
# 8 Palsson
# 9 Johnson
# 10 Nasser
# 11 Sandstrom
# 12 Bonnell
# 13 Saundercock
# 14 Andersson
# 15 Vestrom
# 16 Hewlett
# 17 Rice
# 18 Williams
# 19 Vander Planke
# 20 Masselmani
# 21 Fynney
# 22 Beesley
# 23 McGowan
# 24 Sloper
# 25 Palsson
# 26 Asplund
# 27 Emir
# 28 Fortune
# 29 O'Dwyer
# 30 Todoroff
# 31 Uruchurtu
# 32 Spencer
# 33 Glynn
# 34 Wheadon
# 35 Meyer
# 36 Holverson
# 37 Mamee
# 38 Cann
# 39 Vander Planke
# 40 Nicola-Yarred
# 41 Ahlin
# 42 Turpin
# 43 Kraeff
# 44 Laroche
# 45 Devaney
# 46 Rogers
# 47 Lennon
# 48 O'Driscoll
# 49 Samaan
# 50 Arnold-Franchi
# 51 Panula
# 52 Nosworthy
# 53 Harper
# 54 Faunthorpe
# 55 Ostby
# 56 Woolner
# 57 Rugg
# 58 Novel
# 59 West
# 60 Goodwin
# 61 Sirayanian
# 62 Icard
# 63 Harris
# 64 Skoog
# 65 Stewart
# 66 Moubarek
# 67 Nye
# 68 Crease
# 69 Andersson
# 70 Kink
# 71 Jenkin
# 72 Goodwin
# 73 Hood
# 74 Chronopoulos
# 75 Bing
# 76 Moen
# 77 Staneff
# ...

# %%
def surname(mlist, position):
   return mlist[position]

# %%
train.Name.str.split(',').apply(surname,position=0)
# Out:
# 0               Braund
# 1              Cumings
# 2            Heikkinen
# 3             Futrelle
# 4                Allen
# 5                Moran
# 6             McCarthy
# 7              Palsson
# 8              Johnson
# 9               Nasser
# 10           Sandstrom
# 11             Bonnell
# 12         Saundercock
# 13           Andersson
# 14             Vestrom
# 15             Hewlett
# 16                Rice
# 17            Williams
# 18       Vander Planke
# 19          Masselmani
# 20              Fynney
# 21             Beesley
# 22             McGowan
# 23              Sloper
# 24             Palsson
# 25             Asplund
# 26                Emir
# 27             Fortune
# 28             O'Dwyer
# 29            Todoroff
#             ...
# 861              Giles
# 862              Swift
# 863               Sage
# 864               Gill
# 865            Bystrom
# 866       Duran y More
# 867           Roebling
# 868      van Melkebeke
# 869            Johnson
# ...

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks[drinks.continent=='Africa'].describe()
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.agg(['count','min','max','mean']) #aggregrate
# Out:
#                count  min  max        mean
# continent
# Africa            53    0  376   61.471698
# Asia              44    0  247   37.045455
# Europe            45    0  361  193.777778
# North America     23    1  285  145.434783
# Oceania           16    0  306   89.687500
# South America     12   93  333  175.083333

# %%
drinks.groupby('continent').beer_servings.mean().plot('bar')

# %%
drinks['liquor_max']=drinks.str.max(['beer_servings','spirit_servings','wine_servings'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-38377f9e8de8> in <module>()
# ----> 1 drinks['liquor_max']=drinks.str.max(['beer_servings','spirit_servings','wine_servings'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  liquor_max
# 0                           0.0      Asia         370
# 1                           4.9    Europe         370
# 2                           0.7    Africa         370
# 3                          12.4    Europe         370
# 4                           5.9    Africa         370

# %%
drinks.country[drinks.beer_servings.idxmax()]
# Out:
# 'Namibia'

# %%
drinks.loc[:,'beer_servings':'wine_servings'].apply(max, axis=1)
# Out:
# 0        0
# 1      132
# 2       25
# 3      312
# 4      217
# 5      128
# 6      221
# 7      179
# 8      261
# 9      279
# 10      46
# 11     176
# 12      63
# 13       0
# 14     173
# 15     373
# 16     295
# 17     263
# 18      34
# 19      23
# 20     167
# 21     173
# 22     173
# 23     245
# 24      31
# 25     252
# 26      25
# 27      88
# 28      37
# 29     144
#       ...
# 163    178
# 164     90
# 165    186
# 166    280
# 167     35
# 168     15
# 169    258
# 170    106
# 171      4
# 172     36
# 173     36
# 174    197
# 175     51
# 176     51
# 177     71
# 178     41
# 179     45
# 180    237
# 181    135
# 182    219
# 183     36
# 184    249
# 185    220
# 186    101
# 187     21
# 188    333
# 189    111
# 190      6
# 191     32
# 192     64
# dtype: int64

# %%
drinks['liquor_m']=drinks.loc[:,'beer_servings':'wine_servings'].apply(nm.argmax, axis=1)

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  liquor_max         liquor_m
# 0                           0.0      Asia         370    beer_servings
# 1                           4.9    Europe         370  spirit_servings
# 2                           0.7    Africa         370    beer_servings
# 3                          12.4    Europe         370    wine_servings
# 4                           5.9    Africa         370    beer_servings
