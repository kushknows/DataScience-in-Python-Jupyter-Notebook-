# %%
import numpy as np
x=np.array([[5,6,7,8],[15, 16,17,18],[25,26,27,28]])
x
# Out:
# array([[ 5,  6,  7,  8],
#        [15, 16, 17, 18],
#        [25, 26, 27, 28]])

# %%
x[0:2,1:3] #slicng inn 2d x[r1:r2, c1:c2]
# Out:
# array([[ 6,  7],
#        [16, 17]])

# %%
x=np.array([[[5,6,7,8],[15, 16,17,18],[25,26,27,28]],
          [[51,62,73,84],[151, 162,173,184],[251,262,273,284]]])
x
# Out:
# array([[[  5,   6,   7,   8],
#         [ 15,  16,  17,  18],
#         [ 25,  26,  27,  28]],
#
#        [[ 51,  62,  73,  84],
#         [151, 162, 173, 184],
#         [251, 262, 273, 284]]])

# %%
x[0:1,1:3,1:3] #x[floor,row,column]
# Out:
# array([[[16, 17],
#         [26, 27]]])

# %%
import pandas as pd #used for unstructured dataframe
p=pd.DataFrame({'a':[1,2,3],'b':[4,5,6],'c':[7,8,9]}, index=(1,2,3))
p
# Out:
#    a  b  c
# 1  1  4  7
# 2  2  5  8
# 3  3  6  9

# %%
p[['a','b']]
# Out:
#    a  b
# 1  1  4
# 2  2  5
# 3  3  6

# %%
p.values #for converting into array numpy
# Out:
# array([[1, 4, 7],
#        [2, 5, 8],
#        [3, 6, 9]], dtype=int64)

# %%
data=pd.read_csv(r'C:\Users\KUSH\Downloads\Digit Recognizer\sample_submission.csv',) #comma seperated fil
# index_col=0 particular variable becomes index

# %%
data.head(5)
# Out:
#    ImageId  Label
# 0        1      0
# 1        2      0
# 2        3      0
# 3        4      0
# 4        5      0

# %%
data.dtypes
# Out:
# Label    int64
# dtype: object

# %%
data['ImageId'].mean() #which one is dependent variables=y or independent variables=x
# Out:
# 14000.5

# %%
X=data[['ImageId','ImageId']]
#label
Y=data[['ImageId']]

# %%
X.head(5)
# Out:
#    ImageId  ImageId
# 0        1        1
# 1        2        2
# 2        3        3
# 3        4        4
# 4        5        5

# %%
import matplotlib.pyplot as plt
plt.plot(X,Y,'g--')
plt.xlabel('X_Axis')
plt.ylabel('Y_Axis')
plt.show()

# %%
chips=pd.read_table(r'http://bit.ly/chiporders')
chips
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
#chips.item_price=chips.item_price.astype(float) for converting object itno ...
#chips.item_price.astype(float).min
#chips.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-26d964c32320> in <module>()
#       2 #chips.item_price.astype(float).min
#       3 #chips.dtypes
# ----> 4 chips.item_price=chips.item_price.str.replace('$',' ')
#       5 chips.item_price=chips.item_price.astype(float)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2738         if (name in self._internal_names_set or name in self._metadata or
#    2739                 name in self._accessors):
# -> 2740             return object.__getattribute__(self, name)
#    2741         else:
#    2742             if name in self._info_axis:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in __get__(self, instance, owner)
#     239             # this ensures that Series.str.<method> is well defined
#     240             return self.accessor_cls
# ...

# %%
chips[chips.choice_description.str.contains('Apple').fillna(False)]
len(chips)
# Out:
# 4622

# %%
chips.item_price=chips.item_price.astype(float)

# %%
chips.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
x=chips.choice_description.str.contains('Salsa').dropna() #data sizechanges by dropna
len(x)
# Out:
# 3376

# %%
header=['S.No.','Age','Gender','occupation','Zipcode']
m=pd.read_csv(r'http://bit.ly/movieusers',sep='|'
             ,names=header)

# %%
m.head()
# Out:
#    S.No.  Age Gender  occupation Zipcode
# 0      1   24      M  technician   85711
# 1      2   53      F       other   94043
# 2      3   23      M      writer   32067
# 3      4   24      M  technician   43537
# 4      5   33      F       other   15213

# %%
m.columns
# Out:
# Index(['S.No.', 'Age', 'Gender', 'occupation', 'Zipcode'], dtype='object')

# %%
m.columns.str.replace('Gender','gender')
# Out:
# Index(['S.No.', 'Age', 'gender', 'occupation', 'Zipcode'], dtype='object')

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')

# %% [markdown]
# movies

# %% [markdown]
# movies.head()

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.title.sort_values()
#movies.title.sort_values(ascending=False)
# Out:
# 542                   (500) Days of Summer
# 5                             12 Angry Men
# 201                       12 Years a Slave
# 698                              127 Hours
# 110                  2001: A Space Odyssey
# 910                                   2046
# 596                               21 Grams
# 624                              25th Hour
# 708                       28 Days Later...
# 60                                3 Idiots
# 225                                 3-Iron
# 570                                    300
# 555                           3:10 to Yuma
# 427           4 Months, 3 Weeks and 2 Days
# 824                                     42
# 597                                  50/50
# 203                                  8 1/2
# 170                       A Beautiful Mind
# 941                       A Bridge Too Far
# 571                           A Bronx Tale
# 266                      A Christmas Story
# 86                      A Clockwork Orange
# ...

# %%
movies.sort_values(['genre','duration'])
# Out:
#      star_rating                           title content_rating     genre  \
# 533          7.8                    Run Lola Run              R    Action
# 633          7.7                    The Warriors              R    Action
# 455          7.9                           Taken          PG-13    Action
# 685          7.7                     First Blood              R    Action
# 744          7.6     Mad Max 2: The Road Warrior              R    Action
# 619          7.7                Forbidden Planet         PASSED    Action
# 276          8.1            A Fistful of Dollars              R    Action
# 403          7.9                      Ying xiong          PG-13    Action
# 552          7.8                  Kung Fu Hustle              R    Action
# 740          7.6            The Raid: Redemption              R    Action
# 327          8.0    The Adventures of Robin Hood             PG    Action
# 515          7.8                     Dirty Harry              R    Action
# ...

# %%
m=movies.genre.str.contains('Action','Comedy')
movies[m]
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# 36           8.6                              Saving Private Ryan
# 37           8.6                          Raiders of the Lost Ark
# 43           8.5                            The Dark Knight Rises
# 44           8.5                                        Gladiator
# 45           8.5                       Terminator 2: Judgment Day
# 75           8.4                                           Aliens
# 80           8.4       Star Wars: Episode VI - Return of the Jedi
# 82           8.4                                       Braveheart
# ...

# %%
movies.head()
# Out:
#   star_rating                     title content_rating   genre duration  \
# 0       False  The Shawshank Redemption              R   Crime    False
# 1       False             The Godfather              R   Crime    False
# 2       False    The Godfather: Part II              R   Crime    False
# 3       False           The Dark Knight          PG-13  Action    False
# 4       False              Pulp Fiction              R   Crime    False
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.head()
# Out:
#   star_rating                     title content_rating   genre duration  \
# 0       False  The Shawshank Redemption              R   Crime    False
# 1       False             The Godfather              R   Crime    False
# 2       False    The Godfather: Part II              R   Crime    False
# 3       False           The Dark Knight          PG-13  Action    False
# 4       False              Pulp Fiction              R   Crime    False
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movie=pd.read_csv('http://bit.ly/imdbratings')
movie.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
p=movie.genre.str.contains('Comedy')|movie.genre.str.contains('Action')
movie[p]
# Out:
#     star_rating                                              title  \
# 3             9                                    The Dark Knight
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
# 19          8.7                                          Star Wars
# 20          8.7                                         The Matrix
# 25          8.6                                  Life Is Beautiful
# 29          8.6                                        City Lights
# 35          8.6                                       Modern Times
# 36          8.6                                Saving Private Ryan
# 37          8.6                            Raiders of the Lost Ark
# 43          NaN                              The Dark Knight Rises
# 44          NaN                                          Gladiator
# 45          NaN                         Terminator 2: Judgment Day
# ...

# %%
du=movie.duration>150
du
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 949    False
# 950    False
# 951    False
# 952    False
# 953    False
# 954    False
# 955    False
# 956    False
# 957    False
# 958    False
# 959    False
# 960    False
# 961    False
# 962    False
# 963    False
# 964    False
# 965    False
# 966    False
# 967    False
# 968    False
# 969    False
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: duration, dtype: bool

# %%
d=movie.duration>=150

# %%
movie.duration=movie[d]

# %%
r=movie.star_rating>8.5
movie.star_rating=movie[r]

# %%
movie.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
import pandas as p
m=p.read_csv(r'http://bit.ly/imdbratings')
m.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
i=m.genre.str.contains('Action')|m.genre.str.contains('Comedy')
n=m[i]

# %%
di=n.duration>=150
u=n[di]
sr=u.star_rating>=8.5
u[sr]
# Out:
#     star_rating                  title content_rating   genre  duration  \
# 3           9.0        The Dark Knight          PG-13  Action       152
# 36          8.6    Saving Private Ryan              R  Action       169
# 43          8.5  The Dark Knight Rises          PG-13  Action       165
# 44          8.5              Gladiator              R  Action       155
# 60          8.5               3 Idiots          PG-13  Comedy       170
#
#                                           actors_list
# 3   [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 36     [u'Tom Hanks', u'Matt Damon', u'Tom Sizemore']
# 43  [u'Christian Bale', u'Tom Hardy', u'Anne Hatha...
# 44  [u'Russell Crowe', u'Joaquin Phoenix', u'Conni...
# 60        [u'Aamir Khan', u'Madhavan', u'Mona Singh']

# %%
import pandas as pd
ipl=pd.read_csv(r'C:\Users\KUSH\Documents\matches.csv')

# %%
ipl
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
len(ipl.id)
# Out:
# 636

# %%
len(ipl.season.unique())
# Out:
# 10

# %%
wm=ipl.win_by_wickets.max()
ipl.winner[ipl.win_by_wickets.max()]
# Out:
# 'Kolkata Knight Riders'

# %%
ipl.win_by_runs.max()
# Out:
# 0

# %%
ipl.win_by_runs.min()
p=ipl.win_by_runs=0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-56eb4ed05e93> in <module>()
#       1 ipl.win_by_runs.min()
#       2 p=ipl.win_by_runs=0
# ----> 3 p.head()
#
# AttributeError: 'int' object has no attribute 'head'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-6bb8c191bfd8> in <module>()
# ----> 1 ipl.p
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'p'

# %%
mat=pd.read_csv(r'C:\Users\KUSH\Documents\matches.csv')

# %%
mat.win_by_runs.max()
# Out:
# 146

# %%
mat.iloc[mat.win_by_runs.max()]
# Out:
# id                             147
# season                        2009
# city                     Centurion
# date                    2009-05-06
# team1              Deccan Chargers
# team2               Mumbai Indians
# toss_winner        Deccan Chargers
# toss_decision                  bat
# result                      normal
# dl_applied                       0
# winner             Deccan Chargers
# win_by_runs                     19
# win_by_wickets                   0
# player_of_match          RG Sharma
# venue              SuperSport Park
# umpire1                  MR Benson
# umpire2            HDPK Dharmasena
# umpire3                        NaN
# Name: 146, dtype: object

# %%
mat.iloc[mat.win_by_wickets.idxmax()] #idx return id of row
# Out:
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                           2017-04-07
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %%
mat.iloc[mat.win_by_wickets.idxmin()] #for accessing rows iloc is used
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
ru=mat[mat.win_by_runs!=mat.win_by_runs.min()]
ru[ru.win_by_runs==1]
# Out:
#       id  season          city        date                        team1  \
# 58    59    2017     Hyderabad  2017-05-21               Mumbai Indians
# 105  106    2008        Mumbai  2008-05-21              Kings XI Punjab
# 163  164    2009  Johannesburg  2009-05-17              Kings XI Punjab
# 344  345    2012         Delhi  2012-04-29             Delhi Daredevils
# 350  351    2012          Pune  2012-05-03               Mumbai Indians
# 518  519    2015       Chennai  2015-04-09          Chennai Super Kings
# 598  599    2016         Delhi  2016-04-27                Gujarat Lions
# 614  615    2016    Chandigarh  2016-05-09  Royal Challengers Bangalore
#
#                       team2       toss_winner toss_decision  result  \
# 58   Rising Pune Supergiant    Mumbai Indians           bat  normal
# 105          Mumbai Indians    Mumbai Indians         field  normal
# 163         Deccan Chargers   Deccan Chargers         field  normal
# ...

# %%
mat.season.value_counts().idxmax()
mat.winner.value_counts().idxmax()
len(mat[mat.toss_winner==mat.winner])
# Out:
# 325

# %%
# %matplotlib inline
mat.season.value_counts().plot('bar')
mat.winner.value_counts().plot('bar')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     105                 else:
# --> 106                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     107             except Exception:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in reduction(values, axis, skipna)
#     445         else:
# --> 446             result = getattr(values, meth)(axis)
#     447
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims)
#      25 def _amax(a, axis=None, out=None, keepdims=False):
# ---> 26     return umr_maximum(a, axis, None, out, keepdims)
#      27
#
# TypeError: '>=' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# ...
